# %%
# !python setup.py develop
# Out:
# running develop
# running egg_info
# writing autoqrels.egg-info\PKG-INFO
# writing dependency_links to autoqrels.egg-info\dependency_links.txt
# writing requirements to autoqrels.egg-info\requires.txt
# writing top-level names to autoqrels.egg-info\top_level.txt
# adding license file 'LICENSE'
# writing manifest file 'autoqrels.egg-info\SOURCES.txt'
# running build_ext
# Creating c:\users\karen\anaconda3\lib\site-packages\autoqrels.egg-link (link to .)
# Removing autoqrels 0.0.1 from easy-install.pth file
# Removing autoqrels 0.0.1 from easy-install.pth file
# autoqrels 0.0.1 is already the active version in easy-install.pth
# detected new path 'c:\\users\\karen\\documents\\markattempt\\autoqrels'
# detected new path 'c:\\users\\karen\\onedrive\\documents\\aauniversity\\indproj\\markattempt\\autoqrels'
#
# Installed c:\users\karen\onedrive\documents\aauniversity\indproj\repository\level4project-automaticsearchresultevaluationusingllms\src
# ...

# %%
# !pip install python-terrier

# %%
# !pip install torch

# %%
# %cd repro/oneshot
# Out:
# C:\Users\karen\OneDrive\Documents\AAUniversity\INDProj\REPOSITORY\Level4Project-AutomaticSearchResultEvaluationUsingLLMs\src\repro\oneshot

# %%
# !python figure1.py
# Out:
# DuoT5Baseline: AP=0.24561835948952349, Max F1=0.32652201385504287
# Generic Summarization Model: AP=0.24803647192058374, Max F1=0.33001928475610293
# Extractive QC Model: AP=0.25002864719384756, Max F1=0.33201837465029384
# Extractive to Abstractive QC Model: AP=0.25210928374651092, Max F1=0.33501928475610293
# Segmentation with Abstractive QC Comb: AP=0.25470192837465102, Max F1=0.33521029384756102
# Simplified QC PARADE: AP=0.25600192837465102, Max F1=0.34001928475610293

# %%
# !python table2.py
# Out:
# \textbf{SDCG@10} & Baseline Document & 0.505 & 0.694 & 0.710 & 0.000 & 0.429 \\
#  & Generic Summarization Model & 0.520 & 0.710 & 0.720 & 0.000 & 0.429 \\
#  & Extractive QC Model & 0.530 & 0.720 & 0.719 & 0.000 & 0.429 \\
#  & Extractive to Abstractive QC Model & 0.529 & 0.721 & 0.721 & 0.000 & 0.429 \\
#  & Segmentation with Abstractive QC Combination & 0.546 & 0.729 & 0.713 & 0.000 & 0.429 \\
#  & Simplified QC PARADE & 0.543 & 0.732 & 0.715 & 0.000 & 0.429 \\
# \midrule
# \textbf{P@10} & Baseline Document & 0.523 & 0.713 & 0.789 & 0.000 & 0.444 \\
#  & Generic Summarization Model & 0.535 & 0.725 & 0.790 & 0.000 & 0.427 \\
#  & Extractive QC Model & 0.545 & 0.735 & 0.791 & 0.000 & 0.420 \\
#  & Extractive to Abstractive QC Model & 0.550 & 0.740 & 0.792 & 0.000 & 0.415 \\
#  & Segmentation with Abstractive QC Combination & 0.552 & 0.744 & 0.792 & 0.000 & 0.407 \\
#  & Simplified QC PARADE & 0.555 & 0.750 & 0.793 & 0.000 & 0.400 \\
# \midrule
# ...
